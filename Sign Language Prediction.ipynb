# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#                                               0.0/293.3 kB ? eta -:--:--
#      ----------                              81.9/293.3 kB 1.5 MB/s eta 0:00:01
#      -------------------------              194.6/293.3 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 293.3/293.3 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\dines\appdata\roaming\python\python310\site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\dines\appdata\roaming\python\python310\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\dines\appdata\roaming\python\python310\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dines\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dines\appdata\roaming\python\python310\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dines\appdata\roaming\python\python310\site-packages (from pandas>=0.25->seaborn) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\dines\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
train=pd.read_csv('sign_mnist_train.csv')
test=pd.read_csv('sign_mnist_test.csv')

# %%
train.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8
# 0      3     107     118     127     134     139     143     146     150  \
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780
# 0     153  ...       207       207       207       207       206       206  \
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 164.4 MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7172 entries, 0 to 7171
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 43.0 MB

# %%
train.shape
# Out:
# (27455, 785)

# %%
#Data visualization
f=plt.figure(figsize=(20,6))
ax=f.add_subplot(161)
ax2=f.add_subplot(162)
ax3=f.add_subplot(163)
ax4=f.add_subplot(164)
ax5=f.add_subplot(165)
ax6=f.add_subplot(166)
ax.imshow(train.iloc[0].values[1:].reshape(28,28))
ax2.imshow(train.iloc[5].values[1:].reshape(28,28))
ax3.imshow(train.iloc[20].values[1:].reshape(28,28))
ax4.imshow(train.iloc[456].values[1:].reshape(28,28))
ax5.imshow(train.iloc[999].values[1:].reshape(28,28))
ax6.imshow(train.iloc[1500].values[1:].reshape(28,28))

plt.show()

# %%
labels = train['label'].values
plt.figure(figsize = (14,8))
sns.countplot(x =labels)
# Out:
# <Axes: ylabel='count'>

# %%
X_train = train.drop(["label"],axis=1)
X_test = test.drop(["label"],axis=1)
Y_train = train['label']
Y_test = test['label']
del train['label']
del test['label']

# %%
#Data normalization,CNN works faster
X_train = X_train/255.0
X_test = X_test/255.0
X_train.shape
X_test.shape
# Out:
# (7172, 784)

# %%
#Reshaping
X_train = X_train.values.reshape(-1,28,28,1)
X_test = X_test.values.reshape(-1,28,28,1)
X_train.shape
X_test.shape
# Out:
# (7172, 28, 28, 1)

# %%
#Label encoding
from sklearn.preprocessing import LabelBinarizer
label_binrizer = LabelBinarizer()
Y_train = label_binrizer.fit_transform(Y_train)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

print("x_train shape",X_train.shape)
print("x_test shape",X_val.shape)
print("y_train shape",Y_train.shape)
print("y_test shape",Y_val.shape)
# Out:
# x_train shape (21964, 28, 28, 1)
# x_test shape (5491, 28, 28, 1)
# y_train shape (21964, 24)
# y_test shape (5491, 24)

# %%
plt.imshow(X_train[12][:,:,0],cmap="gray")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import itertools
import tensorflow as tf

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop,Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau


model = tf.keras.models.Sequential([
                        tf.keras.layers.Conv2D(64, (3, 3), activation='relu',padding = 'same', input_shape=(28, 28, 1)),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(128, (3, 3),padding = 'same', activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        tf.keras.layers.Conv2D(512, (3, 3),padding = 'same', activation='relu'),
                        tf.keras.layers.MaxPooling2D(2, 2),
                        
                        tf.keras.layers.Conv2D(512, (3, 3),padding = 'same', activation='relu'),
                        tf.keras.layers.Flatten(),
                        tf.keras.layers.Dense(512, activation='relu'),
                        tf.keras.layers.Dense(24, activation='softmax')])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 128)       73856
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 128)        0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 512)         590336
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 512)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 512)         2359808
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 512)               2359808
#
#  dense_1 (Dense)             (None, 24)                12312
#
# =================================================================
# Total params: 5,396,760
# Trainable params: 5,396,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
#optimizer = Adam(lr=0.003, beta_1=0.9, beta_2=0.999)

model.compile( optimizer='rmsprop' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
epochs = 50 
batch_size = 200

# %%
#Data augmentation
datagen = ImageDataGenerator(
        featurewise_center=False,  
        samplewise_center=False,  
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False, 
        zca_whitening=False,
        rotation_range=15, 
        zoom_range = 0.5,
        width_shift_range=0.15,  
        height_shift_range=0.15, 
        horizontal_flip=True,  
        vertical_flip=False)  

datagen.fit(X_train)

# %%
fig,axe=plt.subplots(2,2)
fig.suptitle('Preview of dataset')
axe[0,0].imshow(X_train[0].reshape(28,28),cmap='gray')
axe[0,0].set_title('label: 3  letter: C')
axe[0,1].imshow(X_train[1].reshape(28,28),cmap='gray')
axe[0,1].set_title('label: 6  letter: F')
axe[1,0].imshow(X_train[2].reshape(28,28),cmap='gray')
axe[1,0].set_title('label: 2  letter: B')
axe[1,1].imshow(X_train[4].reshape(28,28),cmap='gray')
axe[1,1].set_title('label: 13  letter: M')
# Out:
# Text(0.5, 1.0, 'label: 13  letter: M')

# %%
history = model.fit_generator(datagen.flow(X_train,Y_train, batch_size=batch_size),epochs = epochs, validation_data = (X_val,Y_val), steps_per_epoch=X_train.shape[0] // batch_size)
# Out:
# Epoch 1/50
# C:\Users\dines\AppData\Local\Temp\ipykernel_5892\1193075716.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(datagen.flow(X_train,Y_train, batch_size=batch_size),epochs = epochs, validation_data = (X_val,Y_val), steps_per_epoch=X_train.shape[0] // batch_size)
# 109/109 [==============================] - 89s 810ms/step - loss: 3.1444 - accuracy: 0.0611 - val_loss: 2.9204 - val_accuracy: 0.1268
# Epoch 2/50
# 109/109 [==============================] - 88s 806ms/step - loss: 2.7189 - accuracy: 0.1735 - val_loss: 1.9370 - val_accuracy: 0.3892
# Epoch 3/50
# 109/109 [==============================] - 89s 815ms/step - loss: 2.2309 - accuracy: 0.2962 - val_loss: 1.7053 - val_accuracy: 0.4451
# Epoch 4/50
# 109/109 [==============================] - 93s 851ms/step - loss: 1.7426 - accuracy: 0.4359 - val_loss: 0.7624 - val_accuracy: 0.7673
# Epoch 5/50
# 109/109 [==============================] - 92s 841ms/step - loss: 1.2950 - accuracy: 0.5715 - val_loss: 0.6749 - val_accuracy: 0.7683
# Epoch 6/50
# 109/109 [==============================] - 91s 832ms/step - loss: 0.9892 - accuracy: 0.6706 - val_loss: 0.5302 - val_accuracy: 0.8254
# Epoch 7/50
# 109/109 [==============================] - 91s 833ms/step - loss: 0.7565 - accuracy: 0.7450 - val_loss: 0.2854 - val_accuracy: 0.9024
# Epoch 8/50
# 109/109 [==============================] - 91s 833ms/step - loss: 0.5904 - accuracy: 0.7976 - val_loss: 0.1080 - val_accuracy: 0.9669
# Epoch 9/50
# 109/109 [==============================] - 91s 831ms/step - loss: 0.4652 - accuracy: 0.8409 - val_loss: 0.1135 - val_accuracy: 0.9608
# Epoch 10/50
# 109/109 [==============================] - 92s 840ms/step - loss: 0.3808 - accuracy: 0.8719 - val_loss: 0.0832 - val_accuracy: 0.9723
# Epoch 11/50
# 109/109 [==============================] - 91s 835ms/step - loss: 0.3209 - accuracy: 0.8917 - val_loss: 0.0511 - val_accuracy: 0.9836
# Epoch 12/50
# 109/109 [==============================] - 91s 833ms/step - loss: 0.2728 - accuracy: 0.9076 - val_loss: 0.0445 - val_accuracy: 0.9852
# Epoch 13/50
# 109/109 [==============================] - 91s 835ms/step - loss: 0.2325 - accuracy: 0.9213 - val_loss: 0.0140 - val_accuracy: 0.9984
# Epoch 14/50
# 109/109 [==============================] - 91s 839ms/step - loss: 0.2078 - accuracy: 0.9325 - val_loss: 0.0111 - val_accuracy: 0.9971
# Epoch 15/50
# 109/109 [==============================] - 91s 832ms/step - loss: 0.1839 - accuracy: 0.9383 - val_loss: 0.0291 - val_accuracy: 0.9905
# Epoch 16/50
# 109/109 [==============================] - 91s 832ms/step - loss: 0.1679 - accuracy: 0.9423 - val_loss: 0.0599 - val_accuracy: 0.9818
# Epoch 17/50
# 109/109 [==============================] - 92s 840ms/step - loss: 0.1500 - accuracy: 0.9504 - val_loss: 0.0101 - val_accuracy: 0.9965
# Epoch 18/50
# 109/109 [==============================] - 91s 836ms/step - loss: 0.1402 - accuracy: 0.9546 - val_loss: 0.0927 - val_accuracy: 0.9730
# Epoch 19/50
# 109/109 [==============================] - 91s 832ms/step - loss: 0.1351 - accuracy: 0.9541 - val_loss: 0.0054 - val_accuracy: 0.9984
# Epoch 20/50
# 109/109 [==============================] - 91s 833ms/step - loss: 0.1201 - accuracy: 0.9595 - val_loss: 0.0088 - val_accuracy: 0.9962
# Epoch 21/50
# 109/109 [==============================] - 90s 829ms/step - loss: 0.1102 - accuracy: 0.9635 - val_loss: 0.0019 - val_accuracy: 0.9996
# Epoch 22/50
# 109/109 [==============================] - 91s 830ms/step - loss: 0.1061 - accuracy: 0.9642 - val_loss: 0.0031 - val_accuracy: 0.9991
# Epoch 23/50
# 109/109 [==============================] - 91s 833ms/step - loss: 0.0977 - accuracy: 0.9673 - val_loss: 0.0030 - val_accuracy: 0.9989
# Epoch 24/50
# 109/109 [==============================] - 91s 835ms/step - loss: 0.0953 - accuracy: 0.9682 - val_loss: 0.0123 - val_accuracy: 0.9960
# Epoch 25/50
# 109/109 [==============================] - 91s 832ms/step - loss: 0.0883 - accuracy: 0.9716 - val_loss: 0.0046 - val_accuracy: 0.9982
# Epoch 26/50
# 109/109 [==============================] - 90s 829ms/step - loss: 0.0853 - accuracy: 0.9723 - val_loss: 0.0022 - val_accuracy: 0.9995
# Epoch 27/50
# 109/109 [==============================] - 93s 851ms/step - loss: 0.0790 - accuracy: 0.9754 - val_loss: 0.0030 - val_accuracy: 0.9991
# Epoch 28/50
# 109/109 [==============================] - 94s 865ms/step - loss: 0.0768 - accuracy: 0.9748 - val_loss: 0.0033 - val_accuracy: 0.9987
# Epoch 29/50
# 109/109 [==============================] - 93s 849ms/step - loss: 0.0715 - accuracy: 0.9759 - val_loss: 2.3955e-04 - val_accuracy: 1.0000
# Epoch 30/50
# 109/109 [==============================] - 92s 844ms/step - loss: 0.0736 - accuracy: 0.9764 - val_loss: 1.8085e-04 - val_accuracy: 1.0000
# Epoch 31/50
# 109/109 [==============================] - 92s 842ms/step - loss: 0.0673 - accuracy: 0.9774 - val_loss: 0.0121 - val_accuracy: 0.9960
# Epoch 32/50
# 109/109 [==============================] - 91s 836ms/step - loss: 0.0707 - accuracy: 0.9773 - val_loss: 0.0047 - val_accuracy: 0.9982
# Epoch 33/50
# 109/109 [==============================] - 91s 839ms/step - loss: 0.0613 - accuracy: 0.9792 - val_loss: 0.0034 - val_accuracy: 0.9989
# Epoch 34/50
# 109/109 [==============================] - 92s 843ms/step - loss: 0.0646 - accuracy: 0.9793 - val_loss: 4.8544e-04 - val_accuracy: 0.9998
# Epoch 35/50
# 109/109 [==============================] - 91s 839ms/step - loss: 0.0630 - accuracy: 0.9784 - val_loss: 8.2046e-04 - val_accuracy: 0.9998
# Epoch 36/50
# 109/109 [==============================] - 91s 831ms/step - loss: 0.0608 - accuracy: 0.9802 - val_loss: 0.0026 - val_accuracy: 0.9989
# Epoch 37/50
# 109/109 [==============================] - 92s 843ms/step - loss: 0.0585 - accuracy: 0.9816 - val_loss: 2.6091e-04 - val_accuracy: 1.0000
# Epoch 38/50
# 109/109 [==============================] - 117s 1s/step - loss: 0.0545 - accuracy: 0.9816 - val_loss: 0.0038 - val_accuracy: 0.9989
# Epoch 39/50
# 109/109 [==============================] - 121s 1s/step - loss: 0.0513 - accuracy: 0.9836 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 40/50
# 109/109 [==============================] - 121s 1s/step - loss: 0.0528 - accuracy: 0.9823 - val_loss: 0.0016 - val_accuracy: 0.9993
# Epoch 41/50
# 109/109 [==============================] - 121s 1s/step - loss: 0.0492 - accuracy: 0.9828 - val_loss: 0.0053 - val_accuracy: 0.9980
# Epoch 42/50
# 109/109 [==============================] - 121s 1s/step - loss: 0.0531 - accuracy: 0.9823 - val_loss: 0.0191 - val_accuracy: 0.9933
# Epoch 43/50
# 109/109 [==============================] - 122s 1s/step - loss: 0.0534 - accuracy: 0.9824 - val_loss: 1.3867e-04 - val_accuracy: 1.0000
# Epoch 44/50
# 109/109 [==============================] - 94s 858ms/step - loss: 0.0448 - accuracy: 0.9858 - val_loss: 0.0011 - val_accuracy: 0.9995
# Epoch 45/50
# 109/109 [==============================] - 87s 802ms/step - loss: 0.0486 - accuracy: 0.9847 - val_loss: 2.7111e-04 - val_accuracy: 1.0000
# Epoch 46/50
# 109/109 [==============================] - 90s 824ms/step - loss: 0.0420 - accuracy: 0.9860 - val_loss: 0.0011 - val_accuracy: 0.9995
# Epoch 47/50
# 109/109 [==============================] - 95s 873ms/step - loss: 0.0473 - accuracy: 0.9852 - val_loss: 4.4727e-05 - val_accuracy: 1.0000
# Epoch 48/50
# 109/109 [==============================] - 93s 856ms/step - loss: 0.0463 - accuracy: 0.9851 - val_loss: 0.0293 - val_accuracy: 0.9909
# Epoch 49/50
# 109/109 [==============================] - 90s 825ms/step - loss: 0.0415 - accuracy: 0.9871 - val_loss: 4.6771e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 109/109 [==============================] - 90s 829ms/step - loss: 0.0437 - accuracy: 0.9850 - val_loss: 2.9638e-04 - val_accuracy: 0.9998

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# plotting the heatmap
hm = sn.heatmap(data=,
                annot=annot)
  
# displaying the plotted heatmap
plt.show()
